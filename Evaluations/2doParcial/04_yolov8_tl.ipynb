# %% [markdown]
# # Yolov8
#
# En este notebook se entrena un modelo Yolov8 para la segmentación de objetos en imágenes soda, cuadernos y ruedas.

# %%
from ultralytics import YOLO
import torch

# Carga el modelo
model = YOLO('./yolov8x-seg.pt')
# Configura el tamaño de las imágenes
imgsz = 512
# Configura el tamaño del lote
batch = 16
# Configura el optimizador
optim = torch.optim.AdamW(model.parameters(), lr=0.0001)

# %% [markdown]
# ### Entrenando
#
# Para entrenar el modelo se debe ejecutar el siguiente comando:

# %%
results = model.train(data='customdata.yaml', epochs=50, imgsz=imgsz, batch=batch, device="cuda")
# Out:
# New https://pypi.org/project/ultralytics/8.0.208 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.207  Python-3.11.6 torch-2.1.0 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: task=segment, mode=train, model=yolov8x-seg.pt, data=customdata.yaml, epochs=50, patience=50, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=cuda, workers=8, project=None, name=train4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\segment\train4
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1  12319097  ultralytics.nn.modules.head.Segment          [3, 32, 320, [320, 640, 640]]
# YOLOv8x-seg summary: 401 layers, 71753737 parameters, 71753721 gradients
#
# Transferred 651/657 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed
# train: Scanning E:\6° Semestre\Inteligencia Artificial II\SIS421---2-23\Evaluations\2doParcial\Dataset\Moneyv6iyolov8\train\labels.cache... 1302 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1302/1302 [00:00<?, ?it/s]
# train: WARNING  E:\6 Semestre\Inteligencia Artificial II\SIS421---2-23\Evaluations\2doParcial\Dataset\Moneyv6iyolov8\train\images\image62_png.rf.11159f435698e2adcbf94b825e20fa0a.jpg: 1 duplicate labels removed
# train: WARNING  E:\6 Semestre\Inteligencia Artificial II\SIS421---2-23\Evaluations\2doParcial\Dataset\Moneyv6iyolov8\train\images\image62_png.rf.9b1112e55da0df37abbf965464ad30fa.jpg: 1 duplicate labels removed
# train: WARNING  E:\6 Semestre\Inteligencia Artificial II\SIS421---2-23\Evaluations\2doParcial\Dataset\Moneyv6iyolov8\train\images\image62_png.rf.db48263257efa5d4c909ae34cddb9d16.jpg: 1 duplicate labels removed
# val: Scanning E:\6° Semestre\Inteligencia Artificial II\SIS421---2-23\Evaluations\2doParcial\Dataset\Moneyv6iyolov8\valid\labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100%|██████████| 60/60 [00:00<?, ?it/s]
# Plotting labels to runs\segment\train4\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 106 weight(decay=0.0), 117 weight(decay=0.0005), 116 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs\segment\train4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      9.76G     0.6504      1.293      1.815      1.089         25        512: 100%|██████████| 82/82 [01:22<00:00,  1.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
#                    all         60        144       0.11      0.319     0.0815     0.0561     0.0864      0.267     0.0622     0.0319
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      10.3G     0.8674      1.594      1.414      1.236         20        512: 100%|██████████| 82/82 [01:18<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.02s/it]
#                    all         60        144      0.216      0.312      0.162      0.103      0.182      0.276      0.125     0.0598
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      10.3G     0.9603      1.739      1.424      1.307         15        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
#                    all         60        144      0.527      0.546      0.555      0.401      0.531      0.546      0.559      0.389
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      10.3G     0.8911      1.657      1.261       1.26         15        512: 100%|██████████| 82/82 [01:18<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
#                    all         60        144      0.642      0.559      0.636      0.491      0.642      0.559      0.637      0.459
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      10.3G     0.8401      1.563      1.166      1.228          8        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.05s/it]
#                    all         60        144      0.779      0.708      0.782      0.605      0.784      0.714      0.744      0.563
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      9.93G     0.7681      1.354      1.032      1.173         18        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.25it/s]
#                    all         60        144      0.859      0.726      0.834      0.664      0.852      0.736      0.811      0.628
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      10.3G     0.7033      1.263     0.9352      1.127         17        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
#                    all         60        144      0.803      0.432      0.617      0.512      0.767      0.457      0.608      0.459
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      10.3G     0.6541      1.126     0.8717      1.093         25        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.25s/it]
#                    all         60        144      0.745      0.734       0.79      0.647      0.742      0.725      0.777      0.612
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      10.3G     0.6312      1.117     0.8161      1.076         33        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
#                    all         60        144      0.928      0.815      0.915       0.78      0.935      0.814      0.887      0.737
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      10.3G     0.6194      1.093     0.7892      1.068         15        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
#                    all         60        144      0.852      0.804      0.859      0.742      0.822      0.792      0.845      0.683
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      10.3G     0.5866     0.9502     0.7725      1.042         22        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
#                    all         60        144      0.901      0.824      0.925      0.804       0.88      0.801        0.9       0.76
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      10.3G     0.5586      0.923     0.7164      1.029         39        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.38s/it]
#                    all         60        144       0.95       0.85      0.939      0.825      0.949      0.848      0.926      0.792
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      10.3G     0.5591     0.9277     0.6931      1.032         14        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.20s/it]
#                    all         60        144      0.944      0.841      0.917      0.814      0.942      0.836      0.909      0.782
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      10.3G      0.549     0.9032     0.6891      1.021         43        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
#                    all         60        144      0.876      0.909       0.95      0.845      0.893      0.894       0.94      0.809
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      10.4G     0.5162     0.8711     0.6462      1.002         31        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
#                    all         60        144      0.964       0.87      0.944      0.857      0.964       0.87      0.937      0.811
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      10.3G     0.5309     0.8853     0.6522      1.018         14        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
#                    all         60        144      0.927      0.879      0.938      0.851      0.932       0.88      0.941      0.818
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      10.3G      0.497     0.8027     0.5801     0.9872         19        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
#                    all         60        144      0.939      0.933       0.96      0.867      0.985      0.901      0.953      0.837
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      10.3G     0.5033     0.7966     0.5834      0.993         15        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
#                    all         60        144      0.911      0.851      0.907      0.813      0.954      0.813      0.894      0.774
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      10.3G     0.4835     0.7336     0.5757     0.9789         26        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
#                    all         60        144      0.932      0.926      0.961      0.867      0.921      0.903      0.945      0.832
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      10.3G     0.4755     0.7394     0.5668     0.9815         10        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
#                    all         60        144      0.956      0.917      0.969      0.883      0.961      0.916      0.976      0.851
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      10.3G     0.4814      0.746     0.5608     0.9685         25        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
#                    all         60        144       0.94      0.913      0.947      0.865      0.931      0.904       0.94      0.827
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      10.3G     0.4542     0.7303     0.5758     0.9673         15        512: 100%|██████████| 82/82 [01:18<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
#                    all         60        144      0.969      0.899      0.969       0.89      0.972      0.881      0.951      0.846
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      10.3G     0.4635      0.715     0.5398     0.9682         21        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
#                    all         60        144       0.93      0.934      0.966      0.895       0.93      0.923      0.958      0.844
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      10.3G      0.462     0.7053     0.5301     0.9671         14        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
#                    all         60        144       0.95      0.942      0.969      0.878      0.954      0.933      0.956      0.862
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      9.95G     0.4294     0.6449     0.4943     0.9461         33        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
#                    all         60        144       0.94      0.917      0.966      0.873      0.938      0.915       0.96      0.853
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      9.99G     0.4267     0.6255     0.4767     0.9532         34        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
#                    all         60        144      0.971      0.879      0.926      0.843      0.962      0.871      0.925      0.816
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      10.3G     0.4109     0.6035     0.4703     0.9312         40        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
#                    all         60        144      0.957      0.899      0.971      0.872      0.954      0.907      0.967      0.861
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      10.4G     0.4227     0.6238     0.4848     0.9513         21        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
#                    all         60        144      0.975      0.859      0.934       0.87      0.988      0.872      0.951      0.869
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      10.3G     0.3999     0.5728     0.4422     0.9339         26        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.02s/it]
#                    all         60        144      0.965      0.895      0.953      0.882      0.963      0.892       0.95      0.867
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      10.3G     0.4025     0.6028     0.4601     0.9288         21        512: 100%|██████████| 82/82 [01:21<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  1.51s/it]
#                    all         60        144      0.905      0.915      0.961      0.906      0.912      0.921      0.968      0.882
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      10.3G     0.3893     0.5764     0.4367     0.9284         19        512: 100%|██████████| 82/82 [01:15<00:00,  1.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.28s/it]
#                    all         60        144      0.945      0.948      0.972      0.901      0.951      0.955      0.973      0.892
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      9.94G     0.3779     0.5719     0.4194     0.9147         19        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
#                    all         60        144      0.989      0.923      0.973      0.905      0.983      0.906      0.961      0.884
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      10.3G     0.3819     0.5402     0.4027     0.9217         14        512: 100%|██████████| 82/82 [01:22<00:00,  1.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.20s/it]
#                    all         60        144      0.963      0.951      0.981      0.917      0.958      0.943       0.98      0.889
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      10.3G     0.3862     0.5608      0.414     0.9233         18        512: 100%|██████████| 82/82 [01:21<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.21s/it]
#                    all         60        144      0.969      0.898       0.96      0.897      0.967      0.895      0.952      0.886
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      10.3G     0.3618     0.5201     0.3795     0.9151         28        512: 100%|██████████| 82/82 [01:21<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.48s/it]
#                    all         60        144      0.967      0.898      0.962      0.902      0.964      0.898      0.967      0.886
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       36/50        10G     0.3582     0.5195     0.3838     0.9095         21        512: 100%|██████████| 82/82 [01:21<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
#                    all         60        144      0.968      0.922      0.949      0.885      0.965      0.913      0.949      0.867
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      10.3G     0.3567     0.5101     0.3704     0.9061         15        512: 100%|██████████| 82/82 [01:21<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
#                    all         60        144      0.986      0.921      0.958      0.888      0.977      0.912      0.955      0.876
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      9.97G     0.3517     0.4956     0.3758     0.9091         16        512: 100%|██████████| 82/82 [01:21<00:00,  1.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
#                    all         60        144      0.954      0.922      0.969      0.921      0.963       0.93       0.97        0.9
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      10.2G     0.3425     0.4943     0.3468     0.8964         18        512: 100%|██████████| 82/82 [01:21<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.39s/it]
#                    all         60        144      0.979      0.931      0.959      0.913      0.979      0.931      0.964      0.892
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      10.3G     0.3386     0.4803     0.3515     0.8946         28        512: 100%|██████████| 82/82 [01:21<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
#                    all         60        144      0.975      0.928      0.958      0.902      0.944      0.943      0.957       0.89
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      10.2G     0.2861     0.4169     0.3032     0.8823         20        512: 100%|██████████| 82/82 [01:21<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
#                    all         60        144      0.974       0.94      0.979       0.92      0.974      0.946      0.977      0.896
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      10.2G     0.2865     0.3983     0.2873     0.8858          7        512: 100%|██████████| 82/82 [01:22<00:00,  1.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.44s/it]
#                    all         60        144       0.96      0.919      0.975      0.924      0.967      0.924      0.966      0.901
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      9.89G     0.2777     0.3779       0.26     0.8788         13        512: 100%|██████████| 82/82 [01:19<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
#                    all         60        144      0.952      0.948      0.982       0.93      0.938      0.957      0.981      0.907
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      10.3G     0.2752     0.3816     0.2574     0.8793         11        512: 100%|██████████| 82/82 [01:14<00:00,  1.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
#                    all         60        144      0.934      0.963      0.967      0.914      0.931       0.96      0.968      0.897
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      9.92G      0.266     0.3612     0.2526     0.8663         10        512: 100%|██████████| 82/82 [01:13<00:00,  1.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.33it/s]
#                    all         60        144      0.954       0.94      0.969      0.912      0.981      0.918      0.965      0.888
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      9.93G      0.254     0.3413      0.232     0.8568          7        512: 100%|██████████| 82/82 [01:14<00:00,  1.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
#                    all         60        144      0.955      0.954      0.981      0.931      0.952      0.953      0.981      0.908
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      10.2G     0.2478     0.3391     0.2157     0.8592          8        512: 100%|██████████| 82/82 [01:14<00:00,  1.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  1.59s/it]
#                    all         60        144      0.967      0.944      0.982      0.941      0.967      0.944      0.981      0.919
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      10.3G      0.245     0.3335     0.2252     0.8481         11        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.03s/it]
#                    all         60        144      0.989       0.94      0.982      0.936      0.989       0.94      0.982      0.919
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      10.2G     0.2349     0.3299     0.2065      0.849         10        512: 100%|██████████| 82/82 [01:17<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
#                    all         60        144       0.99      0.934      0.979      0.941      0.948       0.96      0.977      0.919
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      10.3G     0.2228     0.3118      0.193     0.8439         11        512: 100%|██████████| 82/82 [01:17<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
#                    all         60        144      0.987      0.938      0.973      0.926      0.979       0.93      0.964      0.906
#
# 50 epochs completed in 1.255 hours.
# Optimizer stripped from runs\segment\train4\weights\last.pt, 143.9MB
# Optimizer stripped from runs\segment\train4\weights\best.pt, 143.9MB
#
# Validating runs\segment\train4\weights\best.pt...
# Ultralytics YOLOv8.0.207  Python-3.11.6 torch-2.1.0 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71723545 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
#                    all         60        144      0.967      0.944      0.982      0.941      0.967      0.944      0.981      0.919
#                   10bs         60         40      0.973      0.975      0.979      0.939      0.973      0.975      0.978      0.928
#                   20bs         60         56      0.962      0.899      0.975      0.945      0.962      0.899      0.976      0.928
#                   50bs         60         48      0.966      0.958      0.991      0.938      0.966      0.958      0.991        0.9
# Speed: 0.2ms preprocess, 18.9ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs\segment\train4

# %% [markdown]
# ### Matriz de confusión

# %%
from IPython.display import display, Image

Image('./runs/segment/train/confusion_matrix.png', width=800)

# %% [markdown]
# ### Labels
#
# Las etiquetas de los objetos son:

# %%
Image('./runs/segment/train/labels.jpg', width=800)

# %% [markdown]
# ### Precision Recall
#
# La precision y recall del modelo son:

# %%
Image('./runs/segment/train/results.png')

# %%
Image('./runs/segment/train/BoxPR_curve.png', width=800)

# %% [markdown]
# ### Predecimos
#
# Predecimos con el siguiente comando:

# %%
from ultralytics import YOLO

model = YOLO('./runs/segment/train/weights/best.pt')
#result = model.predict(source='1', show=True) # predict and save
#print(result)

# %%
result = model.predict(source='./1.jpg', save=True) # predict and save
# Out:
# image 1/1 e:\6 Semestre\Inteligencia Artificial II\SIS421---2-23\Evaluations\2doParcial\1.jpg: 512x512 1 10bs, 1 20bs, 1 50bs, 39.7ms
# Speed: 163.1ms preprocess, 39.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\segment\predict2

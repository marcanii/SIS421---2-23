# %%
import os 
from pathlib import Path

path = Path('./Dataset/Segundoparcialv7icoco-mmdetection/')
imgs = [path/'train'/i for i in os.listdir(path/'train')]
masks = [path/'test'/i for i in os.listdir(path/'train')]

len(imgs), len(masks)
# Out:
# (717, 717)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

img = cv2.imread(str(imgs[202]))
mask = cv2.imread(str(masks[0]))
plt.imshow(img)
plt.show()

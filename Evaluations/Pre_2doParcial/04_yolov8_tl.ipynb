# %% [markdown]
# # Yolov8
#
# En este notebook se entrena un modelo Yolov8 para la segmentación de objetos en imágenes soda, cuadernos y ruedas.

# %%
from ultralytics import YOLO
import torch

# Carga el modelo
model = YOLO('yolov8x-seg.pt')
# Configura el tamaño de las imágenes
imgsz = 512
# Configura el tamaño del lote
batch = 16
# Configura el optimizador
optim = torch.optim.AdamW(model.parameters(), lr=0.0001)

# %% [markdown]
# ### Entrenando
#
# Para entrenar el modelo se debe ejecutar el siguiente comando:

# %%
results = model.train(data='customdata.yaml', epochs=100, imgsz=imgsz, batch=batch, device="cuda")
# Out:
# Ultralytics YOLOv8.0.207  Python-3.11.6 torch-2.1.0 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %% [markdown]
# ### Matriz de confusión

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

ruta_imagen = './runs/segment/train/confusion_matrix.png'
imagen = mpimg.imread(ruta_imagen)
plt.figure(figsize=(12, 10))
plt.imshow(imagen)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Labels
#
# Las etiquetas de los objetos son:

# %%
ruta_imagen = './runs/segment/train/labels.jpg'
imagen = mpimg.imread(ruta_imagen)
plt.figure(figsize=(12, 10))
plt.imshow(imagen)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Precision Recall
#
# La precision y recall del modelo son:

# %%
ruta_imagen = './runs/segment/train/MaskPR_curve.png'
imagen = mpimg.imread(ruta_imagen)
plt.figure(figsize=(12, 10))
plt.imshow(imagen)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Predecimos
#
# Predecimos con el siguiente comando:

# %%
from ultralytics import YOLO

model = YOLO('./models/best_Yolov8.pt')
#result = model.predict(source='1', show=True) # predict and save
#print(result)

# %%
result = model.predict(source='./5.jpg', save=True)
# Out:
# image 1/1 c:\6 Semestre\Inteligencia Artificial II\SIS421---2-23\Evaluations\2doParcial\5.jpg: 512x512 2 ruedas, 2741.4ms
# Speed: 3.0ms preprocess, 2741.4ms inference, 6.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\segment\predict2
